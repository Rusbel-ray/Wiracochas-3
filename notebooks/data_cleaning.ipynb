# %%
# data_cleaning.ipynb

import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Cargar el dataset
data = pd.read_csv('datos_estudiantes.csv')

# Mostrar un resumen inicial del dataset
print(data.info())
print(data.describe())

# Ver si hay valores nulos
print("Valores nulos en el dataset:")
print(data.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1498 entries, 0 to 1497
# Data columns (total 14 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Edad                                       1498 non-null   int64
#  1   Genero                                     1498 non-null   int64
#  2   Promedio_calificaciones_semestre_anterior  1498 non-null   float64
#  3   Asignaturas_reprobadas                     1498 non-null   int64
#  4   Asignaturas_aprobadas                      1498 non-null   int64
#  5   Numero_semestres_matriculado               1498 non-null   int64
#  6   Asistencia                                 1498 non-null   float64
#  7   Distancia_universidad                      1498 non-null   float64
#  8   Trabaja                                    1498 non-null   int64
#  9   Frecuencia_consumo_alcohol                 1498 non-null   int64
#  10  Consumo_tabaco                             1498 non-null   int64
#  11  bica                                       1498 non-null   int64
#  12  trica                                      1498 non-null   int64
#  13  Desercion                                  1498 non-null   int64
# dtypes: float64(3), int64(11)
# memory usage: 164.0 KB
# None
#               Edad       Genero  Promedio_calificaciones_semestre_anterior  \
# count  1498.000000  1498.000000                                1498.000000
# mean     24.019359     0.469292                                  10.278733
# std       3.806477     0.499223                                   5.714373
# min      18.000000     0.000000                                   0.006650
# 25%      21.000000     0.000000                                   5.183891
# 50%      24.000000     0.000000                                  10.675119
# 75%      27.000000     1.000000                                  15.138315
# max      30.000000     1.000000                                  19.954810
#
#        Asignaturas_reprobadas  Asignaturas_aprobadas  \
# count             1498.000000            1498.000000
# mean                 2.026035               3.349132
# std                  1.417984               1.698442
# min                  0.000000               1.000000
# 25%                  1.000000               2.000000
# 50%                  2.000000               3.000000
# 75%                  3.000000               5.000000
# max                  4.000000               6.000000
#
#        Numero_semestres_matriculado   Asistencia  Distancia_universidad  \
# count                   1498.000000  1498.000000            1498.000000
# mean                       5.620160    50.615951              14.821096
# std                        2.862336    28.845719               8.777737
# min                        1.000000     0.022704               0.000000
# 25%                        3.000000    25.774900               7.113740
# 50%                        6.000000    51.144705              15.000000
# 75%                        8.000000    75.638637              22.257527
# max                       10.000000    99.879294              30.000000
#
#            Trabaja  Frecuencia_consumo_alcohol  Consumo_tabaco         bica  \
# count  1498.000000                 1498.000000     1498.000000  1498.000000
# mean      0.528037                    0.960614        0.474633     0.329773
# std       0.499380                    0.821666        0.499523     0.470288
# min       0.000000                    0.000000        0.000000     0.000000
# 25%       0.000000                    0.000000        0.000000     0.000000
# 50%       1.000000                    1.000000        0.000000     0.000000
# 75%       1.000000                    2.000000        1.000000     1.000000
# max       1.000000                    2.000000        1.000000     1.000000
#
#              trica    Desercion
# count  1498.000000  1498.000000
# mean      0.202270     0.567423
# std       0.401826     0.495599
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     1.000000
# 75%       0.000000     1.000000
# max       1.000000     1.000000
# Valores nulos en el dataset:
# Edad                                         0
# Genero                                       0
# Promedio_calificaciones_semestre_anterior    0
# Asignaturas_reprobadas                       0
# Asignaturas_aprobadas                        0
# Numero_semestres_matriculado                 0
# Asistencia                                   0
# Distancia_universidad                        0
# Trabaja                                      0
# Frecuencia_consumo_alcohol                   0
# Consumo_tabaco                               0
# bica                                         0
# trica                                        0
# Desercion                                    0
# dtype: int64

# %%
# Si no hay valores nulos, continuamos con la normalización
# Normalización de las columnas numéricas
scaler = MinMaxScaler()

# Variables que normalizaremos
columns_to_scale = ['Edad', 'Promedio_calificaciones_semestre_anterior',
                    'Asignaturas_reprobadas', 'Asignaturas_aprobadas',
                    'Numero_semestres_matriculado', 'Asistencia',
                    'Distancia_universidad']

data[columns_to_scale] = scaler.fit_transform(data[columns_to_scale])

# Verificamos el dataset limpio
print("Dataset después de la normalización:")
print(data.head())

# Guardar el dataset limpio
data.to_csv('cleaned_dataset.csv', index=False)
# Out:
# Dataset después de la normalización:
#        Edad  Genero  Promedio_calificaciones_semestre_anterior  \
# 0  0.500000       1                                   0.391853
# 1  0.250000       0                                   0.273335
# 2  1.000000       1                                   0.477582
# 3  0.833333       0                                   0.044159
# 4  0.583333       0                                   0.854075
#
#    Asignaturas_reprobadas  Asignaturas_aprobadas  \
# 0                    0.50                    0.4
# 1                    0.00                    0.8
# 2                    0.75                    0.6
# 3                    0.50                    0.2
# 4                    0.00                    0.8
#
#    Numero_semestres_matriculado  Asistencia  Distancia_universidad  Trabaja  \
# 0                      0.888889    0.646272               0.867980        0
# 1                      0.111111    0.045423               0.583106        0
# 2                      0.222222    0.947102               0.718014        1
# 3                      0.777778    0.843147               0.372044        0
# 4                      0.000000    0.296811               0.092450        1
#
#    Frecuencia_consumo_alcohol  Consumo_tabaco  bica  trica  Desercion
# 0                           1               0     1      0          1
# 1                           2               1     1      0          1
# 2                           1               1     0      1          1
# 3                           1               1     0      0          1
# 4                           0               1     0      0          0
